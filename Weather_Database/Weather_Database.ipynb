# %%
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Build basic URL for OpenWeatherMap with weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kerki
# City not found. Skipping...
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | hauterive
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | puerto colombia
# Processing Record 8 of Set 1 | cedar city
# Processing Record 9 of Set 1 | rincon
# Processing Record 10 of Set 1 | cayenne
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | inirida
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | rovaniemi
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | yumen
# Processing Record 17 of Set 1 | chimbote
# Processing Record 18 of Set 1 | uchaly
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | kaili
# Processing Record 22 of Set 1 | airai
# Processing Record 23 of Set 1 | savelugu
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | novoanninskiy
# Processing Record 32 of Set 1 | angoche
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | havelock
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | deputatskiy
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | aksarka
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | la rioja
# Processing Record 42 of Set 1 | champerico
# Processing Record 43 of Set 1 | dakoro
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | oriximina
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | campbellsville
# Processing Record 48 of Set 1 | zhuzhou
# Processing Record 49 of Set 1 | westport
# Processing Record 50 of Set 1 | indramayu
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | nuevo progreso
# Processing Record 3 of Set 2 | san cristobal
# Processing Record 4 of Set 2 | hilo
# Processing Record 5 of Set 2 | martapura
# Processing Record 6 of Set 2 | ballina
# Processing Record 7 of Set 2 | srednekolymsk
# Processing Record 8 of Set 2 | kununurra
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | muroto
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | kungurtug
# Processing Record 14 of Set 2 | gayny
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | sitka
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | george town
# Processing Record 21 of Set 2 | cockburn town
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | geraldton
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | san rafael
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | kudahuvadhoo
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | namatanai
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | seoul
# Processing Record 32 of Set 2 | broken hill
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | catia la mar
# Processing Record 35 of Set 2 | chifeng
# Processing Record 36 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 2 | kahului
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | qasigiannguit
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | houma
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | la ronge
# Processing Record 46 of Set 2 | aklavik
# Processing Record 47 of Set 2 | norden
# Processing Record 48 of Set 2 | ormara
# Processing Record 49 of Set 2 | suoyarvi
# Processing Record 50 of Set 2 | tsumeb
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | praia
# Processing Record 5 of Set 3 | tecpan
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 3 | cairns
# Processing Record 10 of Set 3 | tokur
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | pangnirtung
# Processing Record 13 of Set 3 | uvira
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | batagay-alyta
# Processing Record 16 of Set 3 | viedma
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 3 | guerrero negro
# Processing Record 20 of Set 3 | qaanaaq
# Processing Record 21 of Set 3 | diamantino
# Processing Record 22 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 3 | malatya
# Processing Record 24 of Set 3 | provideniya
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | ankazobe
# Processing Record 29 of Set 3 | oksfjord
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | bay roberts
# Processing Record 32 of Set 3 | bathsheba
# Processing Record 33 of Set 3 | taltal
# Processing Record 34 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | kieta
# Processing Record 37 of Set 3 | narrabri
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | luancheng
# Processing Record 41 of Set 3 | qesarya
# Processing Record 42 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 3 | takoradi
# Processing Record 45 of Set 3 | soyo
# Processing Record 46 of Set 3 | sesheke
# Processing Record 47 of Set 3 | noumea
# Processing Record 48 of Set 3 | roma
# Processing Record 49 of Set 3 | kupang
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | forrest city
# Processing Record 2 of Set 4 | komsomolskiy
# Processing Record 3 of Set 4 | sao filipe
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | san patricio
# Processing Record 6 of Set 4 | goderich
# Processing Record 7 of Set 4 | matadi
# Processing Record 8 of Set 4 | aykhal
# Processing Record 9 of Set 4 | muktsar
# Processing Record 10 of Set 4 | esperance
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | mehamn
# Processing Record 13 of Set 4 | atambua
# Processing Record 14 of Set 4 | zhezkazgan
# Processing Record 15 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 4 | fort nelson
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | massaguet
# Processing Record 19 of Set 4 | akureyri
# Processing Record 20 of Set 4 | port elizabeth
# Processing Record 21 of Set 4 | qandala
# Processing Record 22 of Set 4 | zhangjiakou
# Processing Record 23 of Set 4 | gao
# Processing Record 24 of Set 4 | smidovich
# Processing Record 25 of Set 4 | akkermanovka
# Processing Record 26 of Set 4 | dondo
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 4 | eureka
# Processing Record 30 of Set 4 | evensk
# Processing Record 31 of Set 4 | ondjiva
# Processing Record 32 of Set 4 | aitape
# Processing Record 33 of Set 4 | kodiak
# Processing Record 34 of Set 4 | pitmoaga
# Processing Record 35 of Set 4 | kem
# Processing Record 36 of Set 4 | loikaw
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | tovarkovo
# Processing Record 39 of Set 4 | skhisma
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | fairbanks
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | vzmorye
# Processing Record 45 of Set 4 | pacifica
# Processing Record 46 of Set 4 | teya
# Processing Record 47 of Set 4 | gigmoto
# Processing Record 48 of Set 4 | ullapool
# Processing Record 49 of Set 4 | rocha
# Processing Record 50 of Set 4 | loreto
# Processing Record 1 of Set 5 | axim
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | rio claro
# Processing Record 4 of Set 5 | mezen
# Processing Record 5 of Set 5 | carutapera
# Processing Record 6 of Set 5 | waipawa
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | vallenar
# Processing Record 9 of Set 5 | dalby
# Processing Record 10 of Set 5 | kulhudhuffushi
# Processing Record 11 of Set 5 | luanda
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | sand
# Processing Record 15 of Set 5 | termiz
# Processing Record 16 of Set 5 | tautira
# Processing Record 17 of Set 5 | korla
# Processing Record 18 of Set 5 | bambous virieux
# Processing Record 19 of Set 5 | manakara
# Processing Record 20 of Set 5 | cururupu
# Processing Record 21 of Set 5 | katangli
# Processing Record 22 of Set 5 | tiksi
# Processing Record 23 of Set 5 | codrington
# Processing Record 24 of Set 5 | jacareacanga
# Processing Record 25 of Set 5 | shuangcheng
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | kikwit
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | sistranda
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | biggar
# Processing Record 33 of Set 5 | bayana
# Processing Record 34 of Set 5 | nagtipunan
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | podor
# Processing Record 37 of Set 5 | stuttgart
# Processing Record 38 of Set 5 | te anau
# Processing Record 39 of Set 5 | charleston
# Processing Record 40 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 5 | sibay
# Processing Record 42 of Set 5 | port blair
# Processing Record 43 of Set 5 | nagar karnul
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | progreso
# Processing Record 46 of Set 5 | kamloops
# Processing Record 47 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | the pas
# Processing Record 50 of Set 5 | burica
# City not found. Skipping...
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | sakakah
# Processing Record 4 of Set 6 | kandrian
# Processing Record 5 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 6 | awbari
# Processing Record 7 of Set 6 | puerto del rosario
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | mantua
# Processing Record 10 of Set 6 | hare bay
# Processing Record 11 of Set 6 | tandil
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | shiyan
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | kiunga
# Processing Record 16 of Set 6 | richards bay
# Processing Record 17 of Set 6 | russell
# Processing Record 18 of Set 6 | vardo
# Processing Record 19 of Set 6 | keetmanshoop
# Processing Record 20 of Set 6 | toora-khem
# Processing Record 21 of Set 6 | lorengau
# Processing Record 22 of Set 6 | constitucion
# Processing Record 23 of Set 6 | hokitika
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | brae
# Processing Record 26 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 6 | altay
# Processing Record 28 of Set 6 | doha
# Processing Record 29 of Set 6 | stoicanesti
# Processing Record 30 of Set 6 | beringovskiy
# Processing Record 31 of Set 6 | semme
# Processing Record 32 of Set 6 | mehran
# Processing Record 33 of Set 6 | cascais
# Processing Record 34 of Set 6 | itum-kale
# Processing Record 35 of Set 6 | ossora
# Processing Record 36 of Set 6 | ukiah
# Processing Record 37 of Set 6 | wichita falls
# Processing Record 38 of Set 6 | galesong
# Processing Record 39 of Set 6 | bardiyah
# Processing Record 40 of Set 6 | rio grande
# Processing Record 41 of Set 6 | camana
# Processing Record 42 of Set 6 | gamba
# Processing Record 43 of Set 6 | pacific grove
# Processing Record 44 of Set 6 | wuchang
# Processing Record 45 of Set 6 | hervey bay
# Processing Record 46 of Set 6 | shelburne
# Processing Record 47 of Set 6 | margate
# Processing Record 48 of Set 6 | ilhabela
# Processing Record 49 of Set 6 | guantanamo
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | dehloran
# Processing Record 2 of Set 7 | beidao
# Processing Record 3 of Set 7 | lata
# Processing Record 4 of Set 7 | weligama
# Processing Record 5 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 6 of Set 7 | rafaela
# Processing Record 7 of Set 7 | pionerskiy
# Processing Record 8 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 7 | sahbuz
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | capreol
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | zyryanka
# Processing Record 14 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 7 | hudson bay
# Processing Record 16 of Set 7 | port macquarie
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | ardakan
# Processing Record 19 of Set 7 | dunedin
# Processing Record 20 of Set 7 | okato
# Processing Record 21 of Set 7 | gravdal
# Processing Record 22 of Set 7 | zhigalovo
# Processing Record 23 of Set 7 | ahuimanu
# Processing Record 24 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 7 | manzil salim
# Processing Record 26 of Set 7 | miri
# Processing Record 27 of Set 7 | myitkyina
# Processing Record 28 of Set 7 | thaba-tseka
# Processing Record 29 of Set 7 | sinnamary
# Processing Record 30 of Set 7 | atar
# Processing Record 31 of Set 7 | jumla
# Processing Record 32 of Set 7 | pimenta bueno
# Processing Record 33 of Set 7 | dodola
# Processing Record 34 of Set 7 | grenfell
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | murdochville
# Processing Record 38 of Set 7 | norman wells
# Processing Record 39 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | navapur
# City not found. Skipping...
# Processing Record 42 of Set 7 | karpathos
# Processing Record 43 of Set 7 | tura
# Processing Record 44 of Set 7 | tabou
# Processing Record 45 of Set 7 | port hedland
# Processing Record 46 of Set 7 | zhigansk
# Processing Record 47 of Set 7 | hangu
# Processing Record 48 of Set 7 | camocim
# Processing Record 49 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 50 of Set 7 | puerto escondido
# Processing Record 1 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | wattegama
# Processing Record 3 of Set 8 | lesnyye polyany
# Processing Record 4 of Set 8 | swellendam
# Processing Record 5 of Set 8 | shache
# Processing Record 6 of Set 8 | kutum
# Processing Record 7 of Set 8 | corrente
# Processing Record 8 of Set 8 | grindavik
# Processing Record 9 of Set 8 | miles city
# Processing Record 10 of Set 8 | novyy urgal
# Processing Record 11 of Set 8 | alappuzha
# Processing Record 12 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 8 | port-gentil
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | labrea
# Processing Record 17 of Set 8 | aksay
# Processing Record 18 of Set 8 | itarema
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | chitral
# Processing Record 21 of Set 8 | ancud
# Processing Record 22 of Set 8 | roald
# Processing Record 23 of Set 8 | yenotayevka
# Processing Record 24 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 8 | palu
# Processing Record 26 of Set 8 | khandyga
# Processing Record 27 of Set 8 | mandalgovi
# Processing Record 28 of Set 8 | suntar
# Processing Record 29 of Set 8 | praia da vitoria
# Processing Record 30 of Set 8 | okhotsk
# Processing Record 31 of Set 8 | millinocket
# Processing Record 32 of Set 8 | bubaque
# Processing Record 33 of Set 8 | prince george
# Processing Record 34 of Set 8 | baboua
# City not found. Skipping...
# Processing Record 35 of Set 8 | faya
# Processing Record 36 of Set 8 | manaure
# Processing Record 37 of Set 8 | pangoa
# Processing Record 38 of Set 8 | senneterre
# Processing Record 39 of Set 8 | jaisalmer
# Processing Record 40 of Set 8 | nanakuli
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | nenjiang
# Processing Record 43 of Set 8 | saint-pierre
# Processing Record 44 of Set 8 | arraial do cabo
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | taoudenni
# Processing Record 47 of Set 8 | hasaki
# Processing Record 48 of Set 8 | clyde river
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | lloydminster
# Processing Record 1 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | yar-sale
# Processing Record 4 of Set 9 | sorong
# Processing Record 5 of Set 9 | jutai
# Processing Record 6 of Set 9 | hagerstown
# Processing Record 7 of Set 9 | san andres
# Processing Record 8 of Set 9 | nizhniy kuranakh
# Processing Record 9 of Set 9 | bayanday
# Processing Record 10 of Set 9 | saint-joseph
# Processing Record 11 of Set 9 | maningrida
# Processing Record 12 of Set 9 | calama
# Processing Record 13 of Set 9 | kavaratti
# Processing Record 14 of Set 9 | port hardy
# Processing Record 15 of Set 9 | mahebourg
# Processing Record 16 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 9 | nantucket
# Processing Record 18 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 9 | kodinsk
# Processing Record 20 of Set 9 | halifax
# Processing Record 21 of Set 9 | ende
# Processing Record 22 of Set 9 | mayo
# Processing Record 23 of Set 9 | severo-yeniseyskiy
# Processing Record 24 of Set 9 | erenhot
# Processing Record 25 of Set 9 | tommot
# Processing Record 26 of Set 9 | coihaique
# Processing Record 27 of Set 9 | lamu
# Processing Record 28 of Set 9 | kushmurun
# Processing Record 29 of Set 9 | andenes
# Processing Record 30 of Set 9 | lerik
# Processing Record 31 of Set 9 | mwense
# Processing Record 32 of Set 9 | lyuban
# Processing Record 33 of Set 9 | general roca
# Processing Record 34 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | tongliao
# Processing Record 37 of Set 9 | novosergiyevka
# Processing Record 38 of Set 9 | omsukchan
# Processing Record 39 of Set 9 | paamiut
# Processing Record 40 of Set 9 | luba
# Processing Record 41 of Set 9 | ilulissat
# Processing Record 42 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 9 | boddam
# Processing Record 44 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 9 | marawi
# Processing Record 46 of Set 9 | ayr
# Processing Record 47 of Set 9 | llangefni
# Processing Record 48 of Set 9 | odenthal
# Processing Record 49 of Set 9 | inhambane
# Processing Record 50 of Set 9 | jiuquan
# Processing Record 1 of Set 10 | bulgan
# Processing Record 2 of Set 10 | bethlehem
# Processing Record 3 of Set 10 | genhe
# Processing Record 4 of Set 10 | zhaoyang
# Processing Record 5 of Set 10 | hirado
# Processing Record 6 of Set 10 | santa fe
# Processing Record 7 of Set 10 | turayf
# Processing Record 8 of Set 10 | chalmette
# Processing Record 9 of Set 10 | chute-aux-outardes
# Processing Record 10 of Set 10 | ponta do sol
# Processing Record 11 of Set 10 | santa cruz cabralia
# Processing Record 12 of Set 10 | oranjemund
# Processing Record 13 of Set 10 | amapa
# Processing Record 14 of Set 10 | woodburn
# Processing Record 15 of Set 10 | sangerhausen
# Processing Record 16 of Set 10 | adre
# Processing Record 17 of Set 10 | marsh harbour
# Processing Record 18 of Set 10 | marsala
# Processing Record 19 of Set 10 | vaniyambadi
# Processing Record 20 of Set 10 | pilar
# Processing Record 21 of Set 10 | lower hutt
# Processing Record 22 of Set 10 | ventspils
# Processing Record 23 of Set 10 | gizo
# Processing Record 24 of Set 10 | victoria
# Processing Record 25 of Set 10 | fasa
# Processing Record 26 of Set 10 | talnakh
# Processing Record 27 of Set 10 | panzhihua
# Processing Record 28 of Set 10 | asilah
# Processing Record 29 of Set 10 | quang ngai
# Processing Record 30 of Set 10 | ugoofaaru
# Processing Record 31 of Set 10 | sortavala
# Processing Record 32 of Set 10 | saldanha
# Processing Record 33 of Set 10 | prince rupert
# Processing Record 34 of Set 10 | fare
# Processing Record 35 of Set 10 | tiznit
# Processing Record 36 of Set 10 | macamic
# Processing Record 37 of Set 10 | wundanyi
# Processing Record 38 of Set 10 | alyangula
# Processing Record 39 of Set 10 | wamba
# Processing Record 40 of Set 10 | beloha
# Processing Record 41 of Set 10 | krasnoselkup
# Processing Record 42 of Set 10 | corrales
# Processing Record 43 of Set 10 | fereydun kenar
# Processing Record 44 of Set 10 | san martin
# Processing Record 45 of Set 10 | poum
# Processing Record 46 of Set 10 | sao miguel do araguaia
# Processing Record 47 of Set 10 | cherskiy
# Processing Record 48 of Set 10 | herat
# Processing Record 49 of Set 10 | margosatubig
# Processing Record 50 of Set 10 | porbandar
# Processing Record 1 of Set 11 | biskamzha
# Processing Record 2 of Set 11 | portland
# Processing Record 3 of Set 11 | ust-nera
# Processing Record 4 of Set 11 | nizhniy odes
# Processing Record 5 of Set 11 | nioro
# Processing Record 6 of Set 11 | kefamenanu
# Processing Record 7 of Set 11 | neftcala
# Processing Record 8 of Set 11 | selcuk
# Processing Record 9 of Set 11 | nelson bay
# Processing Record 10 of Set 11 | andra
# Processing Record 11 of Set 11 | great falls
# Processing Record 12 of Set 11 | berlevag
# Processing Record 13 of Set 11 | san isidro
# Processing Record 14 of Set 11 | natal
# Processing Record 15 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 11 | wairoa
# Processing Record 17 of Set 11 | karaton
# Processing Record 18 of Set 11 | voyvozh
# Processing Record 19 of Set 11 | asekeyevo
# Processing Record 20 of Set 11 | ishigaki
# Processing Record 21 of Set 11 | chapais
# Processing Record 22 of Set 11 | zeya
# Processing Record 23 of Set 11 | kamenka
# Processing Record 24 of Set 11 | prince albert
# Processing Record 25 of Set 11 | ahmadnagar
# Processing Record 26 of Set 11 | adrar
# Processing Record 27 of Set 11 | lakeville
# Processing Record 28 of Set 11 | turukhansk
# Processing Record 29 of Set 11 | jeremie
# Processing Record 30 of Set 11 | digha
# Processing Record 31 of Set 11 | lishu
# Processing Record 32 of Set 11 | rio gallegos
# Processing Record 33 of Set 11 | leh
# Processing Record 34 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | porto walter
# Processing Record 36 of Set 11 | ostrovnoy
# Processing Record 37 of Set 11 | san felipe
# Processing Record 38 of Set 11 | matagami
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | bandarbeyla
# Processing Record 41 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 11 | oil city
# Processing Record 44 of Set 11 | purpe
# Processing Record 45 of Set 11 | vila velha
# Processing Record 46 of Set 11 | cifuentes
# Processing Record 47 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | sokur
# Processing Record 50 of Set 11 | jacqueville
# Processing Record 1 of Set 12 | krasnoarmeysk
# Processing Record 2 of Set 12 | skjern
# Processing Record 3 of Set 12 | umm kaddadah
# Processing Record 4 of Set 12 | weatherford
# Processing Record 5 of Set 12 | padang
# Processing Record 6 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 12 | xai-xai
# Processing Record 8 of Set 12 | sechura
# Processing Record 9 of Set 12 | mahajanga
# Processing Record 10 of Set 12 | kuusamo
# Processing Record 11 of Set 12 | piet retief
# Processing Record 12 of Set 12 | safford
# Processing Record 13 of Set 12 | nautla
# Processing Record 14 of Set 12 | longyan
# Processing Record 15 of Set 12 | russellville
# Processing Record 16 of Set 12 | bambanglipuro
# Processing Record 17 of Set 12 | yatou
# Processing Record 18 of Set 12 | blagoveshchensk
# Processing Record 19 of Set 12 | bafata
# Processing Record 20 of Set 12 | de aar
# Processing Record 21 of Set 12 | naron
# Processing Record 22 of Set 12 | matara
# Processing Record 23 of Set 12 | manokwari
# Processing Record 24 of Set 12 | nemuro
# Processing Record 25 of Set 12 | porto novo
# Processing Record 26 of Set 12 | north myrtle beach
# Processing Record 27 of Set 12 | merrill
# Processing Record 28 of Set 12 | lavrentiya
# Processing Record 29 of Set 12 | killybegs
# Processing Record 30 of Set 12 | trinidad
# Processing Record 31 of Set 12 | louis trichardt
# Processing Record 32 of Set 12 | touros
# Processing Record 33 of Set 12 | coahuayana
# Processing Record 34 of Set 12 | la calera
# Processing Record 35 of Set 12 | antalaha
# Processing Record 36 of Set 12 | lamar
# Processing Record 37 of Set 12 | la asuncion
# Processing Record 38 of Set 12 | kaeo
# Processing Record 39 of Set 12 | sayaxche
# Processing Record 40 of Set 12 | urucara
# Processing Record 41 of Set 12 | grand gaube
# Processing Record 42 of Set 12 | juneau
# Processing Record 43 of Set 12 | cap-chat
# Processing Record 44 of Set 12 | bouza
# Processing Record 45 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 12 | baghdad
# Processing Record 47 of Set 12 | clifton springs
# Processing Record 48 of Set 12 | isangel
# Processing Record 49 of Set 12 | waddan
# Processing Record 50 of Set 12 | nichinan
# Processing Record 1 of Set 13 | olinda
# Processing Record 2 of Set 13 | puri
# Processing Record 3 of Set 13 | gra liyia
# Processing Record 4 of Set 13 | bandiagara
# Processing Record 5 of Set 13 | dutse
# Processing Record 6 of Set 13 | sosnovo-ozerskoye
# Processing Record 7 of Set 13 | ust-kut
# Processing Record 8 of Set 13 | ambon
# Processing Record 9 of Set 13 | zaria
# Processing Record 10 of Set 13 | ersekcsanad
# Processing Record 11 of Set 13 | rudarpur
# Processing Record 12 of Set 13 | kasempa
# Processing Record 13 of Set 13 | fjerritslev
# Processing Record 14 of Set 13 | callaway
# Processing Record 15 of Set 13 | borogontsy
# Processing Record 16 of Set 13 | nuuk
# Processing Record 17 of Set 13 | zapolyarnyy
# Processing Record 18 of Set 13 | lima
# Processing Record 19 of Set 13 | mirnyy
# Processing Record 20 of Set 13 | dawei
# Processing Record 21 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 13 | elban
# Processing Record 23 of Set 13 | syracuse
# Processing Record 24 of Set 13 | anadyr
# Processing Record 25 of Set 13 | carballo
# Processing Record 26 of Set 13 | gat
# Processing Record 27 of Set 13 | mpanda
# Processing Record 28 of Set 13 | buin
# Processing Record 29 of Set 13 | mangai
# Processing Record 30 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 31 of Set 13 | hirara
# Processing Record 32 of Set 13 | zhengjiatun
# Processing Record 33 of Set 13 | half moon bay
# Processing Record 34 of Set 13 | chara
# Processing Record 35 of Set 13 | salinas
# Processing Record 36 of Set 13 | omboue
# Processing Record 37 of Set 13 | high level
# Processing Record 38 of Set 13 | pangai
# Processing Record 39 of Set 13 | fukue
# Processing Record 40 of Set 13 | filadelfia
# Processing Record 41 of Set 13 | prokudskoye
# Processing Record 42 of Set 13 | bourail
# Processing Record 43 of Set 13 | kobilja glava
# Processing Record 44 of Set 13 | spencer
# Processing Record 45 of Set 13 | presidencia roque saenz pena
# Processing Record 46 of Set 13 | matameye
# City not found. Skipping...
# Processing Record 47 of Set 13 | urambo
# Processing Record 48 of Set 13 | minna
# Processing Record 49 of Set 13 | erlenbach
# Processing Record 50 of Set 13 | chernyshevskiy
# Processing Record 1 of Set 14 | pangkalanbuun
# Processing Record 2 of Set 14 | vila franca do campo
# Processing Record 3 of Set 14 | camalu
# Processing Record 4 of Set 14 | honiara
# Processing Record 5 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 14 | port harcourt
# Processing Record 7 of Set 14 | mudigere
# Processing Record 8 of Set 14 | denpasar
# Processing Record 9 of Set 14 | hofn
# Processing Record 10 of Set 14 | glendive
# Processing Record 11 of Set 14 | kursavka
# Processing Record 12 of Set 14 | yinchuan
# Processing Record 13 of Set 14 | conde
# Processing Record 14 of Set 14 | lubaczow
# Processing Record 15 of Set 14 | chimoio
# Processing Record 16 of Set 14 | pitimbu
# Processing Record 17 of Set 14 | asau
# Processing Record 18 of Set 14 | lucapa
# Processing Record 19 of Set 14 | victor harbor
# Processing Record 20 of Set 14 | villamontes
# Processing Record 21 of Set 14 | macapa
# Processing Record 22 of Set 14 | ahipara
# Processing Record 23 of Set 14 | koslan
# Processing Record 24 of Set 14 | invermere
# Processing Record 25 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 14 | acopiara
# Processing Record 27 of Set 14 | vikhorevka
# Processing Record 28 of Set 14 | vaitape
# Processing Record 29 of Set 14 | whitehorse
# Processing Record 30 of Set 14 | mount isa
# Processing Record 31 of Set 14 | aden
# Processing Record 32 of Set 14 | tucumcari
# Processing Record 33 of Set 14 | kiruna
# Processing Record 34 of Set 14 | havre-saint-pierre
# Processing Record 35 of Set 14 | sarkand
# Processing Record 36 of Set 14 | clayton
# Processing Record 37 of Set 14 | conway
# Processing Record 38 of Set 14 | talcahuano
# Processing Record 39 of Set 14 | dongsheng
# Processing Record 40 of Set 14 | gerash
# Processing Record 41 of Set 14 | terrace bay
# Processing Record 42 of Set 14 | otane
# Processing Record 43 of Set 14 | llanes
# Processing Record 44 of Set 14 | vao
# Processing Record 45 of Set 14 | zunyi
# Processing Record 46 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | hualmay
# Processing Record 48 of Set 14 | dakar
# Processing Record 49 of Set 14 | fonte boa
# Processing Record 50 of Set 14 | gzhatsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | novyy starodub
# Processing Record 2 of Set 15 | vorontsovka
# Processing Record 3 of Set 15 | ha giang
# Processing Record 4 of Set 15 | bulungu
# Processing Record 5 of Set 15 | meadow lake
# Processing Record 6 of Set 15 | obluche
# City not found. Skipping...
# Processing Record 7 of Set 15 | san francisco
# Processing Record 8 of Set 15 | yulara
# Processing Record 9 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 15 | henties bay
# Processing Record 11 of Set 15 | souris
# Processing Record 12 of Set 15 | el cope
# Processing Record 13 of Set 15 | fernley
# Processing Record 14 of Set 15 | kampong thum
# Processing Record 15 of Set 15 | chaoyang
# Processing Record 16 of Set 15 | vangaindrano
# Processing Record 17 of Set 15 | cove
# Processing Record 18 of Set 15 | nakonde
# Processing Record 19 of Set 15 | qazvin
# Processing Record 20 of Set 15 | churapcha
# Processing Record 21 of Set 15 | solwezi
# Processing Record 22 of Set 15 | nsoko
# Processing Record 23 of Set 15 | udachnyy
# Processing Record 24 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 15 | christchurch
# Processing Record 26 of Set 15 | manuk mangkaw
# Processing Record 27 of Set 15 | mersing
# Processing Record 28 of Set 15 | vestmannaeyjar
# Processing Record 29 of Set 15 | havoysund
# Processing Record 30 of Set 15 | petukhovo
# Processing Record 31 of Set 15 | maceio
# Processing Record 32 of Set 15 | haines junction
# Processing Record 33 of Set 15 | lazaro cardenas
# Processing Record 34 of Set 15 | coolum beach
# Processing Record 35 of Set 15 | ejura
# Processing Record 36 of Set 15 | luderitz
# Processing Record 37 of Set 15 | elat
# Processing Record 38 of Set 15 | jasper
# Processing Record 39 of Set 15 | upata
# Processing Record 40 of Set 15 | novikovo
# Processing Record 41 of Set 15 | yerbogachen
# Processing Record 42 of Set 15 | kortkeros
# Processing Record 43 of Set 15 | sur
# Processing Record 44 of Set 15 | mindelo
# Processing Record 45 of Set 15 | west lake stevens
# Processing Record 46 of Set 15 | edgewater
# Processing Record 47 of Set 15 | obama
# Processing Record 48 of Set 15 | bairiki
# Processing Record 49 of Set 15 | santa maria
# Processing Record 50 of Set 15 | quatre cocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_columns = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_columns]
city_data_df.tail(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 681        Yerbogachen      RU  61.2767  108.0108     56.93        67
# 682          Kortkeros      RU  61.8106   51.5806     57.20        66
# 683                Sur      OM  22.5667   59.5289     91.53        46
# 684            Mindelo      CV  16.8901  -24.9804     74.75        69
# 685  West Lake Stevens      US  47.9934 -122.1018     81.63        61
# 686          Edgewater      US  28.9889  -80.9023     87.39        67
# 687              Obama      JP  35.4958  135.7460     71.64        90
# 688            Bairiki      KI   1.3292  172.9752     82.40        83
# 689        Santa Maria      BR -29.6842  -53.8069     72.70        49
# 690       Quatre Cocos      MU -20.2078   57.7625     74.08        72
#
#      Cloudiness  Wind Speed Current Description
# 681          63        1.90       broken clouds
# 682           0        2.59           clear sky
# 683           0       12.03           clear sky
# 684          75       19.15       broken clouds
# 685           1        5.99           clear sky
# 686         100       16.31     overcast clouds
# 687         100       18.43     overcast clouds
# 688          75        9.86       broken clouds
# 689           0        4.94           clear sky
# 690          56       16.15          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
